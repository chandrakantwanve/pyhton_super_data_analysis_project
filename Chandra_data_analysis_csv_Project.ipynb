# %%
import pandas as pd

# %%
customers_list = ['custno','firstname','lastname','gender','age','profession','contactNo','emailId','city',
                  'state','isActive','createdDate','UpdatedDate']
products_list = ['productno','productName','Description','isActive','createdDate','UpdatedDate']
transactions_list = ['txnno','txndate','custno','amount','productno','spendby']

# %%
# data_cust=pd.read_csv('file path',names=colu)

# %% [markdown]
# ### Usecase-1 Load all three csv datasets in Pandas Data frames and display first 5 records.

# %%
data_customer=pd.read_csv("C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\CSV_s1\\customers.csv")
data_product=pd.read_csv('C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\CSV_s1\\products.csv')
data_transactions=pd.read_csv('C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\CSV_s1\\transactions.csv')

# %%
data_customer.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive       createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  21-09-2017 12:38
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  22-05-2017 05:29
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  03-09-2017 12:11
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  16-02-2017 04:05
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  15-05-2017 07:34
#
#         UpdatedDate
# 0  18-10-2017 12:12
# 1  18-10-2017 12:12
# 2  18-10-2017 12:12
# 3  18-10-2017 12:12
# 4  18-10-2017 12:12

# %%
data_product.head()
# Out:
#    productno productName Description isActive       createdDate  \
# 0          1    Product1  pgqorighfa        Y  03-04-2017 07:58
# 1          2    Product2  lmndaaweth        Y  21-09-2017 12:38
# 2          3    Product3  urifeubrhh        Y  08-09-2017 10:32
# 3          4    Product4  rlpcjxfarp        Y  22-05-2017 05:29
# 4          5    Product5  hzcpozsgfc        Y  02-02-2017 08:40
#
#         UpdatedDate
# 0  18-10-2017 12:12
# 1  18-10-2017 12:12
# 2  18-10-2017 12:12
# 3  18-10-2017 12:12
# 4  18-10-2017 12:12

# %%
data_transactions.head()
# Out:
#    txnno           txndate  custno  amount  productno spendby
# 0      1  18-10-2017 12:31     923    2559        376    Card
# 1      2  18-10-2017 12:31     219    1706        151    Card
# 2      3  18-10-2017 12:31     927    3462        707    Cash
# 3      4  18-10-2017 12:31     806     865        539    Card
# 4      5  18-10-2017 12:31     958    2494         25    Card

# %% [markdown]
# ### Usecase-2 Display only those customers from CSV_s1, who purchased more than 3 products

# %%
data_transactions.groupby('custno').filter(lambda data_transactions: data_transactions['custno'].count()>3)['custno'].unique()
# Out:
# array([326, 167, 753, 828,   4, 578, 558, 237,  86, 537, 187, 241, 331,
#        735, 391, 356, 321, 709, 989], dtype=int64)

# %% [markdown]
# ### Usecase-3 Display top 5 most demanded products from CSV_s1

# %%
data_transactions['productno'].value_counts().head()
# Out:
# 82     5
# 427    5
# 900    5
# 768    5
# 849    4
# Name: productno, dtype: int64

# %% [markdown]
# ### Usecase-4 Display top 5 transactions amount from CSV_s1

# %%
df6=data_transactions.sort_values('amount',ascending=False).head()
df6
# Out:
#      txnno           txndate  custno  amount  productno spendby
# 556    557  18-10-2017 12:31     670    4996        509    Card
# 305    306  18-10-2017 12:31     448    4992        427    Cash
# 574    575  18-10-2017 12:31     305    4981        549    Card
# 531    532  18-10-2017 12:31     230    4980        658    Card
# 232    233  18-10-2017 12:31     287    4966        685    Card

# %% [markdown]
# ### Usecase-5 Display distinct professions from CSV_s1

# %%
df3=data_customer['profession'].unique()
df3
# Out:
# array(['B', 'S'], dtype=object)

# %% [markdown]
# ### Usecase-6 Display highest age in CSV_s1 customer’s dataset

# %%
df7=data_customer['age'].max()
df7
# Out:
# 64

# %% [markdown]
# ### Usecase-7 Display custno, gender, age, profession, contactno, productno, productName,txndate, spendby, amount from CSV_s1 for custno = 923

# %%
data_customer.loc[data_customer['custno']==923]
# Out:
#      custno firstname lastname gender  age profession  contactNo  \
# 922     923   Russell  Walters      F   46          B      25436
#
#                  emailId      city  state isActive       createdDate  \
# 922  esears55@ma1lbox.us  Cuthbert  Odell        Y  30-07-2017 01:30
#
#           UpdatedDate
# 922  18-10-2017 12:12

# %%
df=pd.concat([data_customer,data_product,data_transactions],axis=1)

df.loc[922,['firstname','custno', 'gender', 'age', 'profession', 'contactNo', 'productno', 'productName','txndate', 'spendby', 'amount']]
# Out:
# firstname               Russell
# custno                      923
# custno                      847
# gender                        F
# age                          46
# profession                    B
# contactNo                 25436
# productno                   923
# productno                   672
# productName          Product923
# txndate        18-10-2017 12:31
# spendby                    Card
# amount                     1948
# Name: 922, dtype: object

# %%
df1 = pd.merge(pd.merge(data_transactions[data_transactions['custno']==923],data_product,on='productno',how='inner'),data_customer,on='custno',how='inner')
df1
# Out:
#    txnno           txndate  custno  amount  productno spendby productName  \
# 0      1  18-10-2017 12:31     923    2559        376    Card  Product376
# 1    335  18-10-2017 12:31     923    2303        113    Card  Product113
# 2    933  18-10-2017 12:31     923    4553        644    Cash  Product644
#
#   Description isActive_x     createdDate_x  ... gender age profession  \
# 0  yrvkpocxka          Y  06-09-2017 05:06  ...      F  46          B
# 1  fktwodxvig          Y  22-03-2017 06:41  ...      F  46          B
# 2  pfmsjwfntn          Y  08-01-2017 06:23  ...      F  46          B
#
#   contactNo              emailId      city  state isActive_y  \
# 0     25436  esears55@ma1lbox.us  Cuthbert  Odell          Y
# 1     25436  esears55@ma1lbox.us  Cuthbert  Odell          Y
# 2     25436  esears55@ma1lbox.us  Cuthbert  Odell          Y
#
#       createdDate_y     UpdatedDate_y
# 0  30-07-2017 01:30  18-10-2017 12:12
# 1  30-07-2017 01:30  18-10-2017 12:12
# ...

# %% [markdown]
# # Usecase-8 Load all three PSV (pipe separated values) dataset in Pandas Data frames and display first 5 records.

# %%
customer_text=pd.read_csv('C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\PSV_s2\\customers.txt',delimiter='|')
product_text=pd.read_csv('C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\PSV_s2\\products.txt',delimiter='|')
transactions_text=pd.read_csv('C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\PSV_s2\\transactions.txt',delimiter='|')

# %% [markdown]
# # Usecase-9 Load all three JSON datasets in Pandas Data frames and display first 5 records.

# %%
customer_json=pd.read_json("C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\JSON_s3\\customers.json",  lines=True)
product_json=pd.read_json("C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\JSON_s3\\products.json",lines=True)
transactions_json=pd.read_json("C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\JSON_s3\\transactions.json", lines=True)

# %% [markdown]
# # Usecase-10 Load all three XML datasets in Pandas Data frames and display first 5 records

# %%
customers_xml=pd.read_xml("C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\XML_s4\\customers.xml")
product_xml=pd.read_xml("C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\XML_s4\\products.xml")
transactions_xml=pd.read_xml("C:\\Users\\INTEGRAL COMPUTER\\python data science\\python_project1_ankursir\\XML_s4\\transactions.xml")

# %% [markdown]
# # Usecase-11 disply the Non-active customers and not active product

# %%
df=data_customer[data_customer['isActive']=='N']
df
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 24       25     Kevin       Owen      F   38          B      48304
# 49       50      Lois     Keller      M   39          S      44490
# 74       75      Fred     Cooper      F   45          B      89963
# 99      100    Mickey    Delaney      M   37          S      87012
# 124     125     Chase    McGowan      F   55          B      50472
# 149     150     Ethan     Hayden      M   46          S      81122
# 174     175   Francis    Harding      F   32          B      34637
# 199     200    Jordan      Hodge      M   57          S      57436
# 224     225      Alan   Gonzalez      F   42          B      52858
# 249     250   Madison      Baird      M   51          S      46333
# 274     275     Marty     Phelps      F   42          B      59501
# 299     300      Carl      Jones      M   54          S      72811
# 324     325     Linda         Le      F   47          B      82182
# ...

# %%
df=data_product[data_product['isActive']=='N']
df
# Out:
#      productno  productName Description isActive       createdDate  \
# 24          25    Product25  xezxnwznyq        N  16-09-2017 09:15
# 49          50    Product50  xskpiytvps        N  27-09-2017 10:10
# 74          75    Product75  bloajtdkam        N  18-07-2017 08:04
# 99         100   Product100  odwwhkmwgj        N  01-09-2017 07:06
# 124        125   Product125  tpnrincqjw        N  18-09-2017 05:18
# 149        150   Product150  ifsdrptnrs        N  03-02-2017 03:56
# 174        175   Product175  fljogzsvxj        N  30-03-2017 05:24
# 199        200   Product200  mloljjazrh        N  02-06-2017 03:45
# 224        225   Product225  dzjxykxpxd        N  17-01-2017 06:25
# 249        250   Product250  laefxzfnas        N  07-07-2017 09:52
# 274        275   Product275  wmkmecunek        N  22-06-2017 01:06
# 299        300   Product300  ehblapeonb        N  03-09-2017 12:40
# 324        325   Product325  vbmeyxtwvp        N  23-04-2017 05:52
# ...

# %% [markdown]
# # Usecase-12 Display distinct spendby form transactions table

# %%
df=data_transactions['spendby'].unique()
df
# Out:
# array(['Card', 'Cash'], dtype=object)

# %% [markdown]
# # Usecase-13 Display the customers who's age more than 60 form customers.csv

# %%
df=data_customer[data_customer['age'] > 60]
df
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 12       13     Kelly   Rutledge      F   62          B      32334
# 19       20    Evelyn       Vang      M   61          S      36284
# 58       59   Randall    Lambert      F   64          B      41458
# 60       61     Kevin      Crane      F   61          B      45742
# 84       85       Roy    Ferrell      F   63          B      56168
# ..      ...       ...        ...    ...  ...        ...        ...
# 941     987     Frank  Donaldson      F   64          B      82695
# 957     926    Elaine     Powell      M   61          S      70040
# 975     944     Vicky    Hawkins      M   64          S      51353
# 983     952     Bobby    Estrada      M   62          S      51056
# 993     962    Evelyn     Stokes      M   61          S      37284
#
#                         emailId                       city       state  \
# 12        kfranco34@b1zmail.net                   Hamilton    Broadvue
# ...
